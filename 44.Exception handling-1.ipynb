# %% [markdown]
#     property decorator
#
#     monkey patching

# %% [markdown]
# ## Exception handling

# %% [markdown]
# #### error
#
#                 there are three types of error:
#
#                     1. compile time error
#
#                     2. Logical error
#
#                     3. run time error

# %% [markdown]
# ## compile time error

# %%
if True
    print('hello')
# Out:
#   Cell In[1], line 1
#     if True
#            ^
# SyntaxError: expected ':'

# %%
for in [23,45,56]:
    print('hello')
# Out:
#   Cell In[2], line 1
#     for in [23,45,56]:
#         ^
# SyntaxError: invalid syntax

# %%
for _ in range(10):
    print('hello world')
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world

# %% [markdown]
# ## Logical Error

# %%
ls = [10,20,30,40,50]

# %%
for i in range(len(ls)):
    ls[i] = ls[i] // 2

# %%
ls
# Out:
# [5, 10, 15, 20, 25]

# %% [markdown]
# ## Run time error

# %%
a = int(input('Enter a: '))
b = int(input('Enter b: '))

print(a + b)
# Out:
# Enter a:  10
# Enter b:  ksjdfkjs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 a = int(input('Enter a: '))
# ----> 2 b = int(input('Enter b: '))
#       4 print(a + b)
#
# ValueError: invalid literal for int() with base 10: 'ksjdfkjs'

# %%
a = int(input('Enter a: '))
b = int(input('Enter b: '))

print(a / b)
# Out:
# Enter a:  20
# Enter b:  3
# 6.666666666666667

# %%
a = int(input('Enter a: '))
b = int(input('Enter b: '))

print(a / b)
print("bye")
# Out:
# Enter a:  10
# Enter b:  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 4
#       1 a = int(input('Enter a: '))
#       2 b = int(input('Enter b: '))
# ----> 4 print(a / b)
#       5 print("bye")
#
# ZeroDivisionError: division by zero

# %% [markdown]
#     try
#
#     except
#
#     else
#
#     finally

# %%
import builtins

# %%
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
a = int(input('Enter a: '))
b = int(input('Enter b: '))

try:
    print(a / b)
except Exception as e:
    print(e)
print('bye')
# Out:
# Enter a:  20
# Enter b:  0
# division by zero
# bye

# %%
a = int(input('Enter a: '))
b = int(input('Enter b: '))

try:
    print(a / b)
except Exception as e:
    print(e)
print('bye')
# Out:
# Enter a:  jhkjsdf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a = int(input('Enter a: '))
#       2 b = int(input('Enter b: '))
#       4 try:
#
# ValueError: invalid literal for int() with base 10: 'jhkjsdf'

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except Exception as e:
    print(f"please enter a number")
print('bye')
# Out:
# Enter a:  sdfsddfs
# please enter a number
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except Exception as e:
    print(f"please enter a number")
print('bye')
# Out:
# Enter a:  10
# Enter b:  0
# please enter a number
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except ZeroDivisionError as e:
    print("Can not divide a number by zero")
except ValueError as e:
    print("Please enter a number")
except Exception as e:
    print(e)
print('bye')
# Out:
# Enter a:  20
# Enter b:  0
# Can not divide a number by zero
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except ZeroDivisionError as e:
    print("Can not divide a number by zero")
except ValueError as e:
    print("Please enter a number")
except Exception as e:
    print(e)
print('bye')
# Out:
# Enter a:  20
# Enter b:  sfkjsgdjk
# Please enter a number
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except ZeroDivisionError as e:
    print("Can not divide a number by zero")
except ValueError as e:
    print("Please enter a number")
except Exception as e:
    print(e)
else:
    print("else block execute only when there is no error in try block")
print('bye')
# Out:
# Enter a:  23
# Enter b:  3
# 7.666666666666667
# else block execute only when there is no error in try block
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except ZeroDivisionError as e:
    print("Can not divide a number by zero")
except ValueError as e:
    print("Please enter a number")
except Exception as e:
    print(e)
else:
    print("else block execute only when there is no error in try block")
print('bye')
# Out:
# Enter a:  10
# Enter b:  0
# Can not divide a number by zero
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except ZeroDivisionError as e:
    print("Can not divide a number by zero")
except ValueError as e:
    print("Please enter a number")
except Exception as e:
    print(e)
else:
    print("else block execute only when there is no error in try block")

finally:
    print("finally block will execute no matters what...")
print('bye')
# Out:
# Enter a:  10
# Enter b:  4
# 2.5
# else block execute only when there is no error in try block
# finally block will execute no matters what...
# bye

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a / b)
except ZeroDivisionError as e:
    print("Can not divide a number by zero")
except ValueError as e:
    print("Please enter a number")
except Exception as e:
    print(e)
else:
    print("else block execute only when there is no error in try block")

finally:
    print("finally block will execute no matters what...")
print('bye')
# Out:
# Enter a:  jkslfhksdj
# Please enter a number
# finally block will execute no matters what...
# bye

# %%
path = input('Enter file path: ')
file = open(path)
data = file.read()
print(data)
file.close()
# Out:
# Enter file path:  new.txt
# hello world

# %%
path = input('Enter file path: ')
file = open(path)
data = file.read()
print(data)
file.close()
# Out:
# Enter file path:  kjgkjfs.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 path = input('Enter file path: ')
# ----> 2 file = open(path)
#       3 data = file.read()
#       4 print(data)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kjgkjfs.txt'

# %%
try:
    path = input('Enter file path: ')
    file = open(path)
    data = file.read()
    print(data)
    file.close()
except FileNotFoundError as e:
    print(f"File not found...")
except Exception as e:
    print(e)
# Out:
# Enter file path:  kjhkjsdfk
# File not found...

# %%
try:
    path = input('Enter file path: ')
    file = open(path)
except FileNotFoundError as e:
    print(f"File not found...")
except Exception as e:
    print(e)
else:
    data = file.read()
    print(data)
    file.close()
# Out:
# Enter file path:  new.txt
# hello world

# %%
while True:
    try:
        path = input('Enter file path: ')
        file = open(path)
    except FileNotFoundError as e:
        print(f"File not found...")
    except Exception as e:
        print(e)
    else:
        data = file.read()
        print(data)
        file.close()
        break
# Out:
# Enter file path:  kjhksdf
# File not found...
# Enter file path:  lkhjlosi
# File not found...
# Enter file path:  lkdhlksj
# File not found...
# Enter file path:  akjrhyweiuor
# File not found...
# Enter file path:  xcnvbmcn
# File not found...
# Enter file path:  new.txt
# hello world

# %% [markdown]
#     raise
#
#     assert
