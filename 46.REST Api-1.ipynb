# %%
import requests

# %%
lat = 26.922070
lon = 75.778885
api_key = 'eee4a71bedc70754cdc0748dc1f421cf'
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat=26.92207&lon=75.778885&appid=eee4a71bedc70754cdc0748dc1f421cf

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.headers
# Out:
# {'Server': 'openresty', 'Date': 'Fri, 21 Jun 2024 14:00:13 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '474', 'Connection': 'keep-alive', 'X-Cache-Key': '/data/2.5/weather?lat=26.92&lon=75.78', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST'}

# %%
data = resp.content
data
# Out:
# b'{"coord":{"lon":75.7789,"lat":26.9221},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":296.83,"feels_like":297.71,"temp_min":296.83,"temp_max":296.83,"pressure":1003,"humidity":94},"visibility":2500,"wind":{"speed":4.12,"deg":290},"clouds":{"all":75},"dt":1718978338,"sys":{"type":1,"id":9170,"country":"IN","sunrise":1718928217,"sunset":1718978023},"timezone":19800,"id":8199371,"name":"Rambagh","cod":200}'

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'coord': {'lon': 75.7789, 'lat': 26.9221},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 296.83,
#   'feels_like': 297.71,
#   'temp_min': 296.83,
#   'temp_max': 296.83,
#   'pressure': 1003,
#   'humidity': 94},
#  'visibility': 2500,
#  'wind': {'speed': 4.12, 'deg': 290},
#  'clouds': {'all': 75},
#  'dt': 1718978338,
#  'sys': {'type': 1,
#   'id': 9170,
#   'country': 'IN',
#   'sunrise': 1718928217,
#   'sunset': 1718978023},
#  'timezone': 19800,
#  'id': 8199371,
#  'name': 'Rambagh',
#  'cod': 200}

# %%
api_key = 'eee4a71bedc70754cdc0748dc1f421cf'
city_name = 'jaipur'
url = f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}"
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=jaipur&appid=eee4a71bedc70754cdc0748dc1f421cf'

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# {'coord': {'lon': 75.8167, 'lat': 26.9167},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 297.77,
#   'feels_like': 298.74,
#   'temp_min': 297.77,
#   'temp_max': 297.77,
#   'pressure': 1002,
#   'humidity': 94},
#  'visibility': 3000,
#  'wind': {'speed': 4.12, 'deg': 290},
#  'clouds': {'all': 75},
#  'dt': 1718979015,
#  'sys': {'type': 1,
#   'id': 9170,
#   'country': 'IN',
#   'sunrise': 1718928209,
#   'sunset': 1718978013},
#  'timezone': 19800,
#  'id': 1269515,
#  'name': 'Jaipur',
#  'cod': 200}

# %%
data.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
data['main']
# Out:
# {'temp': 297.77,
#  'feels_like': 298.74,
#  'temp_min': 297.77,
#  'temp_max': 297.77,
#  'pressure': 1002,
#  'humidity': 94}

# %%
current_temp = data['main']['temp']
min_temp = data['main']['temp_min']
max_temp = data['main']['temp_max']

# %%
current_temp
# Out:
# 297.77

# %%
min_temp
# Out:
# 297.77

# %%
max_temp
# Out:
# 297.77

# %%
try:
    a = int(input('Enter a: '))
    b = int(input('Enter b: '))
    print(a/b)
except Exception as e:
    url = "https://webhook.site/0f962a9b-eea9-4dc3-acf8-8fc3a16819a8"
    requests.post(url, data=e.args[0])
# Out:
# Enter a:  2
# Enter b:  0

# %%
{
    'current_time':'',
    
}

# %%
import requests

def get_temp(city_name):
    api_key = 'eee4a71bedc70754cdc0748dc1f421cf'
    url = f"https://api.openweathermap.org/data/2.5/weather?"

    dict1 = {
        'q':city_name,
        'appid':api_key
    }
    
    resp = requests.get(url, params=dict1)
    if resp.status_code == 200:
        data = resp.json()
        current_temp = data['main']['temp']
        min_temp = data['main']['temp_min']
        max_temp = data['main']['temp_max']
        print(f"Current temp: {current_temp}")
        print(f"Min temp: {min_temp}")
        print(f"max_temp: {max_temp}")
        print()
        print('-'*100)
        print('-'*100)
        print()
    else:
        print(f"Error Occured Status code: {resp.status_code} Reason: {resp.reason}")

# %%
get_temp('jaipur')
# Out:
# Current temp: 306.77
# Min temp: 306.77
# max_temp: 306.77
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
while True:
    get_temp(input('Enter city name: '))
# Out:
# Enter city name:  alwar
# Current temp: 312.12
# Min temp: 312.12
# max_temp: 312.12
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Enter city name:  pune
# Current temp: 300
# Min temp: 300
# max_temp: 300
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Enter city name:  ajmer
# Current temp: 306.51
# Min temp: 306.51
# max_temp: 306.51
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ...
